# %% [markdown]
# ## Python Keywords

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
import sys
sys.version
# Out:
# '3.10.9 | packaged by Anaconda, Inc. | (main, Mar  1 2023, 18:18:15) [MSC v.1916 64 bit (AMD64)]'

# %% [markdown]
# # Python Identifiers

# %%
# Python is cases sensitive
MANI = 123
mani
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Python is cases sensitive
#       2 MANI = 123
# ----> 3 mani
#
# NameError: name 'mani' is not defined

# %%
MANI = 123
MANI

# %%
abc = 567
abc

# %%
#Python identifier have no length limit

abbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb =122
abbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbbb

# %%
#Python Identifier should not start with digit 
122amk = 555
122amk

# %%
amk122 = 555
amk122

# %%
# Special Charaters are not allowed in Python
@123 = "ammis"
@123

# %%
amk@123 = "avula"
amk@123

# %%
#Only Special Character " __" is allowed

amk_mani = "avula"
amk_mani

# %%
#Keywords are not allowed to as python identifier

import = 13
import

# %% [markdown]
# ## VARIABLES

# %%
# A Python variable is reserved memory location to store the values. It results the integer object retun

a = 110
id(a) # Memory location of "a"

# %%
b= 111
id (b)

# %%
hex(id(b))

# %%
#in case we assaigned same value of two identifiers then memory allocation location is sameb 

c =10
d =10
id (c)
id (d)

# %%
d = d +10 #variable is overwriting
d

# %%
intvar = 1223  # int variable
floatvar = 5.66 #float variable
strvar = "Manikanta_Avula"  #string variable 
print (intvar)
print (floatvar)
print (strvar)
# Out:
# 1223
# 5.66
# Manikanta_Avula

# %% [markdown]
# ## Data Types
#  Interger | Float | Boolean | Complex | str

# %%
import sys
val1 = 10
print (type(val1))
print (sys.getsizeof(val1))
# Out:
# <class 'int'>
# 28

# %%
val2 = 50.20   # float data type
print (type(val2))  # give result what type of data it is 
print (sys.getsizeof(val2))  #give the result float ojects in bytes
print( isinstance(val2, float)) # give the result instance of float
# Out:
# <class 'float'>
# 24
# True

# %%
val3 = 5+10j  #complex data type
print (type (val3))
print ( (sys.getsizeof(val3)) )
print(isinstance(val3, complex ))
# Out:
# <class 'complex'>
# 32
# True

# %%
bool1 = True
bool1
# Out:
# True

# %%
bool2 = False
bool2

# %%
bool(0) # 0 indicates the false value
# Out:
# False

# %%
bool (1) # 1 indicates the True Value
# Out:
# True

# %%
bool (2)
# Out:
# True

# %%
bool (5.55)
# Out:
# True

# %%
bool (None)
# Out:
# False

# %%
bool (True)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %% [markdown]
# # STRING DATA TYPE

# %% [markdown]
# # String Creation

# %%
str1 = 'manikanta' # string creation using single quotes
str2 = "Manikanta" # String Creation using double quotes
str3 = ''' Avula
           Manikanta'''  # String Cretion using Double Quotes
str1 = str1 *10
str1
# Out:
# 'manikantamanikantamanikantamanikantamanikantamanikantamanikantamanikantamanikantamanikanta'

# %%
len(str1)
# Out:
# 90

# %% [markdown]
# # String Indexing

# %%
str1 = "MANIKANTA"

# %%
str1[0] # 0 is the starting element if stringin forword indexing
# Out:
# 'm'

# %%
str1 [-9] #0 is the last element if stringin backword indexing
# Out:
# 'm'

# %%
str1[-1]
# Out:
# 'a'

# %%
str1[5]
# Out:
# 'a'

# %%
str1[11]
# Out:
# 'n'

# %% [markdown]
# # String Slicing

# %%
st1 = "ABCDEFGHIJKLM"
st1
# Out:
# 'ABCDEFGHIJKLM'

# %%
len (st1)
# Out:
# 13

# %%
st1[0:5]
# Out:
# 'ABCDE'

# %%
st1[6:12]
# Out:
# 'GHIJKL'

# %%
st1[-6 :]
# Out:
# 'HIJKLM'

# %%
st1[0] = 'm' # Strings are immutable, once create the string we can't modify the string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 st1[0] = 'm'
#
# TypeError: 'str' object does not support item assignment

# %%
st1[ 2: -5]
# Out:
# 'CDEFGH'

# %%
del st1 # to delete the string
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 del st1
#
# NameError: name 'st1' is not defined

# %% [markdown]
# # String Functions
#
# strip  | rstrip | lstrip  | strip (argument )  | replace | lower | upper | count | isupper | is lower

# %%
name = " avulamanikanta      "
name
# Out:
# ' avulamanikanta      '

# %%
name.strip()  # Strip () function is used to remove all white spaces from begining & ending
# Out:
# 'avulamanikanta'

# %%
name.rstrip ()   #rstrip () Function is used to remove all white spaces from ending
# Out:
# ' avulamanikanta'

# %% [markdown]
# name.lstrip ()  #lstrip () is used to remove all white spaces from begining

# %%
name = "*************Avula Manikanta********************"
name
# Out:
# '*************Avula Manikanta********************'

# %%
name.strip('*')  # Strip function with argument, remove all extra special character from string
# Out:
# 'Avula Manikanta'

# %%
name="Avula Manikanta"
name
# Out:
# 'Avula Manikanta'

# %%
name.lower() # lower () function converts the all any upppercase letters to lowercase letters
# Out:
# 'avula manikanta'

# %%
name.upper ()  # upper () function converts all any uppercase letters to lower case letters
# Out:
# 'AVULA MANIKANTA'

# %%
name.count ("Avula") # count () function ishow many times repeted the particular word or string element
# Out:
# 1

# %%
name.replace("Avula","Hello") # this function is used to replaed the substring
# Out:
# 'Hello Manikanta'

# %%
name.startswith ("Avula") # this give the boolean result TRUE if given argument is matched with first substring
# Out:
# True

# %%
name.startswith("Manikanta") # this give the boolean result fALSE if given argument is matched with first substring
# Out:
# False

# %%
name.endswith("Avula")  # this give the boolean result false if given argument is matched with last substring
# Out:
# False

# %%
name.endswith("Manikanta")  # this give the boolean result true if given argument is matched with last substring
# Out:
# True

# %%
name.split () # this function is divided string into substring
# Out:
# ['Avula', 'Manikanta']

# %%
name.isupper () # returns the boolean value, if all elements is true then only it is TRUE
# Out:
# False

# %%
name.islower()  # returns the boolean value, if all elements is true then only it is TRUE
# Out:
# False

# %% [markdown]
# ## TYPE CASTING
# it means convert one data type into other data type

# %% [markdown]
# ### Int to other data types

# %%
num = 55
num
# Out:
# 55

# %%
num1 = str(55) # convert integer into string
num1
# Out:
# '55'

# %%
num2 = float (55) # Convert integer into float
num2
# Out:
# 55.0

# %%
num2 = complex (55, 1) # Convert integer into complex
num2
# Out:
# (55+1j)

# %%
num3 = complex (55)
num3
# Out:
# (55+0j)

# %%
num4 = bool  (55) # to convert integer to bool , except 0 all results are the True
num4
# Out:
# True

# %%
num5 = bool (1)
num5
# Out:
# True

# %%
num6 = bool (0)
num6
# Out:
# False

# %%
num7 = bool (-1)
num7
# Out:
# True

# %% [markdown]
# ### Float to Other Data Types
#
# we can't convert float  into complex

# %%
flt = 10.00
flt
# Out:
# 10.0

# %%
flt1 = float (10.00) # convert the float into integer
flt1
# Out:
# 10.0

# %%
flt2 = float (10) # convert the float into integer
flt2
# Out:
# 10.0

# %%
flt3 = float (True) # convert the float to boolean
flt3
# Out:
# 1.0

# %%
 flt4 = float (False) # convert the float to boolean
flt4
# Out:
# 0.0

# %%
flt5 = float (1+2j) # we can't convert float  into complex
flt5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 flt5 = float (1+2j)
#       2 flt5
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %% [markdown]
# ### Boolean to Other data Types
#
# Everything is possible in Boolean to other data types

# %%
bool (10)
# Out:
# True

# %%
bool ()
# Out:
# False

# %%
bool (0)
# Out:
# False

# %%
bool (-8)
# Out:
# True

# %%
bool (1+2j)
# Out:
# True

# %%
bool (0+0j)
# Out:
# False

# %%
bool (50+0j)
# Out:
# True

# %%
bool ("Mani")
# Out:
# True

# %% [markdown]
# ### Complex to OtherDataTypes
# Complex to String is NOT Possible

# %%
complex (55)
# Out:
# (55+0j)

# %%
complex (True)
# Out:
# (1+0j)

# %%
complex (False)
# Out:
# 0j

# %%
complex (55.00)
# Out:
# (55+0j)

# %%
complex (55,44)
# Out:
# (55+44j)

# %%
complex ("MANI")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 complex ("MANI")
#
# ValueError: complex() arg is a malformed string

# %%
# Difference between Data type to Data Structure
Data type ---> Data type is we can assign only one value
Data Structure ----> it is collection of data types and more than one values we can assign
